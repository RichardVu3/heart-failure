# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')

# %%
data = pd.read_csv("heart_failure.csv")

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.shape
# Out:
# (918, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
data.isnull().any()
# Out:
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
for column in data.columns:
    print("{}: ".format(column), data[column].unique())
# Out:
# Age:  [40 49 37 48 54 39 45 58 42 38 43 60 36 44 53 52 51 56 41 32 65 35 59 50
#  47 31 46 57 55 63 66 34 33 61 29 62 28 30 74 68 72 64 69 67 73 70 77 75
#  76 71]
# Sex:  ['M' 'F']
# ChestPainType:  ['ATA' 'NAP' 'ASY' 'TA']
# RestingBP:  [140 160 130 138 150 120 110 136 115 100 124 113 125 145 112 132 118 170
#  142 190 135 180 108 155 128 106  92 200 122  98 105 133  95  80 137 185
#  165 126 152 116   0 144 154 134 104 139 131 141 178 146 158 123 102  96
#  143 172 156 114 127 101 174  94 148 117 192 129 164]
# Cholesterol:  [289 180 283 214 195 339 237 208 207 284 211 164 204 234 273 196 201 248
#  267 223 184 288 215 209 260 468 188 518 167 224 172 186 254 306 250 177
#  227 230 294 264 259 175 318 216 340 233 205 245 194 270 213 365 342 253
#  277 202 297 225 246 412 265 182 218 268 163 529 100 206 238 139 263 291
#  229 307 210 329 147  85 269 275 179 392 466 129 241 255 276 282 338 160
#  156 272 240 393 161 228 292 388 166 247 331 341 243 279 198 249 168 603
# ...

# %%
# Get the columns with numeric data
data._get_numeric_data().columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# # 1. Visualization

# %%
# Generate pairs of objects of a list
def combination(alist):
    bag = []
    for i in range(len(alist)):
        for j in range(i+1, len(alist)):
            bag.append((alist[i], alist[j]))
    return bag


# Access frame position inside subplots
def frame(x, y):
    bag = []
    for i in range(x):
        for j in range(y):
            bag.append([i, j])
    return bag

# %%
def visualize_each_feature(data):
    for column in ['Age', 'MaxHR', 'RestingBP']:
        plt.figure(column)
        sns.set(rc={'figure.figsize': (25,5)})
        sns.countplot(x=column, data=data).set_title("{}".format(column), fontsize=20)
    
    fig, axes = plt.subplots(2,3, figsize=(15,15))
    frames = frame(2,3)
    columns = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
    for column in range(len(columns)):
        a, b = frames[column]
        plot = sns.countplot(ax=axes[a, b], x=columns[column], data=data)
        axes[a, b].set_title(columns[column].upper(), fontsize=15)
        for p in plot.patches:
            plot.annotate('{}'.format(p.get_height()), (p.get_x() + 0.3, p.get_height() + 5))
            
visualize_each_feature(data)

# %%
sns.pairplot(data, hue='HeartDisease', corner=True)

# %% [markdown]
# # 2. Machine Learning

# %%
from scipy.stats import norm

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score, plot_roc_curve
from sklearn.svm import SVC

import warnings
warnings.filterwarnings('ignore')

plt.rcdefaults()
color = sns.color_palette()
sns.set_style('darkgrid')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# Visualize the proportion of Regular Rider
plt.figure(figsize=(10, 5))
sns.countplot(x=data['HeartDisease'])
plt.title('The number of Patient vs Non-patient', fontsize=20)
# Out:
# Text(0.5, 1.0, 'The number of Patient vs Non-patient')

# %% [markdown]
# 0 is non-patient, 1 is patient

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
# Get the columns with numeric data
num_cols = set(data._get_numeric_data().columns.tolist())

# %%
non_num_cols = set(data.columns).difference(num_cols)

# %%
num_cols
# Out:
# {'Age',
#  'Cholesterol',
#  'FastingBS',
#  'HeartDisease',
#  'MaxHR',
#  'Oldpeak',
#  'RestingBP'}

# %%
non_num_cols
# Out:
# {'ChestPainType', 'ExerciseAngina', 'RestingECG', 'ST_Slope', 'Sex'}

# %%
# Check the correlation between Numeric features
corr_matrix = data[list(num_cols)].corr()
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr_matrix, vmax=1, annot=True, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# No multicollinearity detected => all these numeric columns can be used to train the model

# %% [markdown]
# ## 2.1 Feature Engineering

# %%
X = data.drop(columns=['HeartDisease'])
y = data['HeartDisease']

# %%
# One Hot Encoding for categorical features
X = pd.get_dummies(X, drop_first=True)

# %%
# Split the dataset to train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
# Standard scale the numerical features ("Age", "AnnualSalary")
sc = StandardScaler()
X_train.iloc[:, :-1] = sc.fit_transform(X_train.iloc[:, :-1])
X_test.iloc[:, :-1] = sc.transform(X_test.iloc[:, :-1])

# %% [markdown]
# ## 2.2 Logistic regression

# %% [markdown]
# ### 2.2.1 Without hyperparameter tuning

# %%
logreg = LogisticRegression(class_weight='balanced') # because y value is imbalanced
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       129
#            1       0.86      0.86      0.86       147
#
#     accuracy                           0.85       276
#    macro avg       0.85      0.85      0.85       276
# weighted avg       0.85      0.85      0.85       276

# %%
# Print the AUC score
y_score = logreg.decision_function(X_test)
auc_score = roc_auc_score(y_test, y_score)
print("AUC = {}".format(auc_score))
# Out:
# AUC = 0.9226915572430523

# %%
# Plot the ROC
plot_roc_curve(logreg, X_test, y_test)

# %% [markdown]
# ### 2.2.2 With hyperparameter tuning

# %%
logreg = LogisticRegression()
param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [i/100.0 for i in (1, 1000)],
    'class_weight': ['balanced'],
    'multi_class': ['auto', 'ovr', 'multinomial']
}

grid = GridSearchCV(logreg, param_grid, cv=5, scoring='roc_auc', verbose=True, n_jobs=-1)
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# {'C': 0.01,
#  'class_weight': 'balanced',
#  'multi_class': 'multinomial',
#  'penalty': 'l2'}

# %%
best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       129
#            1       0.87      0.86      0.87       147
#
#     accuracy                           0.86       276
#    macro avg       0.86      0.86      0.86       276
# weighted avg       0.86      0.86      0.86       276

# %%
# Print the AUC score
y_score = best_model.decision_function(X_test)
auc_score = roc_auc_score(y_test, y_score)
print("AUC = {}".format(auc_score))
# Out:
# AUC = 0.927437641723356

# %%
# Plot the ROC
plot_roc_curve(best_model, X_test, y_test)

# %% [markdown]
# ## 2.3 SVM

# %% [markdown]
# ### 2.3.1 Without hyperparameter tuning

# %%
svc = SVC(class_weight='balanced') # because y value is imbalanced
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87       129
#            1       0.87      0.90      0.89       147
#
#     accuracy                           0.88       276
#    macro avg       0.88      0.88      0.88       276
# weighted avg       0.88      0.88      0.88       276

# %%
# Print the AUC score
y_score = svc.decision_function(X_test)
auc_score = roc_auc_score(y_test, y_score)
print("AUC = {}".format(auc_score))
# Out:
# AUC = 0.9212149976269577

# %%
# Plot the ROC
plot_roc_curve(svc, X_test, y_test)

# %% [markdown]
# ### 2.3.2 Hyperparameter for SVM

# %%
svc = SVC()
param_grid = {
    'C': [i/100.0 for i in range(1, 100)],
    'class_weight': ['balanced'],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale','auto'],
    'decision_function_shape': ['ovo','ovr']
}

grid = GridSearchCV(svc, param_grid, cv=5, scoring='roc_auc', verbose=True, n_jobs=-1)
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 1584 candidates, totalling 7920 fits
# {'C': 0.4,
#  'class_weight': 'balanced',
#  'decision_function_shape': 'ovo',
#  'gamma': 'scale',
#  'kernel': 'rbf'}

# %%
best_model = grid.best_estimator_
y_pred = best_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       129
#            1       0.88      0.90      0.89       147
#
#     accuracy                           0.88       276
#    macro avg       0.88      0.88      0.88       276
# weighted avg       0.88      0.88      0.88       276

# %%
# Print the AUC score
y_score = best_model.decision_function(X_test)
auc_score = roc_auc_score(y_test, y_score)
print("AUC = {}".format(auc_score))
# Out:
# AUC = 0.9273849074513527

# %%
# Plot the ROC
plot_roc_curve(best_model, X_test, y_test)
